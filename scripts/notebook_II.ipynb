# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/home/orlando_linux/alura_challange/csv_gold/csv_info_clean.csv",parse_dates=['Month-Year'])
df_2 = pd.read_csv("/home/orlando_linux/alura_challange/csv_gold/csv_info_clean_agg.csv",parse_dates=['Month-Year'])

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12722 entries, 0 to 12721
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Month-Year         12722 non-null  datetime64[ns]
#  1   SENADOR            12722 non-null  object
#  2   VALOR_REEMBOLSADO  12722 non-null  float64
#  3   Contagem_Mes       12722 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 397.7+ KB

# %%
df_2['VALOR_REEMBOLSADO'].sum()
# Out:
# 309619383.78

# %%
tem_nulos
# Out:
# False

# %%
df[(df['SENADOR'] == 'EDUARDO AMORIM') & (df['ANO'] == 2015) & (df['MES'] == 8)].sort_values(by='VALOR_REEMBOLSADO', ascending=False)
# Out:
#          ANO  MES         SENADOR  \
# 147067  2015    8  EDUARDO AMORIM
# 147068  2015    8  EDUARDO AMORIM
# 147066  2015    8  EDUARDO AMORIM
# 147027  2015    8  EDUARDO AMORIM
# 147044  2015    8  EDUARDO AMORIM
# 147043  2015    8  EDUARDO AMORIM
# 147070  2015    8  EDUARDO AMORIM
# 147076  2015    8  EDUARDO AMORIM
# 147033  2015    8  EDUARDO AMORIM
# 147075  2015    8  EDUARDO AMORIM
# 147074  2015    8  EDUARDO AMORIM
# 147069  2015    8  EDUARDO AMORIM
# 147079  2015    8  EDUARDO AMORIM
# 147071  2015    8  EDUARDO AMORIM
# 147029  2015    8  EDUARDO AMORIM
# 147034  2015    8  EDUARDO AMORIM
# 147072  2015    8  EDUARDO AMORIM
# 147073  2015    8  EDUARDO AMORIM
# 147078  2015    8  EDUARDO AMORIM
# 147030  2015    8  EDUARDO AMORIM
# 147077  2015    8  EDUARDO AMORIM
# 147032  2015    8  EDUARDO AMORIM
# 147049  2015    8  EDUARDO AMORIM
# 147047  2015    8  EDUARDO AMORIM
# 147052  2015    8  EDUARDO AMORIM
# 147053  2015    8  EDUARDO AMORIM
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame with columns 'Name', 'Date', and 'Spending'

# Create a pivot table
pivot_df = pd.pivot_table(df, values='VALOR_REEMBOLSADO',
                           index='SENADOR', columns='ANO', aggfunc='sum', 
                          fill_value=0, margins=True, margins_name='Total')

# Display the pivot table
pivot_df.tail(10)
# Out:
# ANO                     2009         2010         2011         2012  \
# SENADOR
# WEVERTON ROCHA          0.00         0.00         0.00         0.00
# WILDER MORAIS           0.00         0.00         0.00     67136.14
# WILSON SANTIAGO         0.00         0.00    282758.27         0.00
# WIRLANDE DA LUZ         0.00         0.00         0.00         0.00
# ZENAIDE MAIA            0.00         0.00         0.00         0.00
# ZEQUINHA MARINHO        0.00         0.00         0.00         0.00
# ZEZÉ PERRELLA           0.00         0.00    161942.97    335890.42
# ZÉ SANTANA              0.00         0.00         0.00         0.00
# ÂNGELA PORTELA          0.00         0.00    380769.17    414270.32
# Total             8931061.81  10760010.57  19004502.48  23354742.37
#
# ANO                      2013         2014         2015         2016  \
# SENADOR
# WEVERTON ROCHA           0.00         0.00         0.00         0.00
# ...

# %%
pivot_df[pivot_df.index == ""]

senadores_desejados = ['EDUARDO AMORIM']

# Filtrando o DataFrame pivotado para os senadores desejados
pivot_df[pivot_df.index.isin(senadores_desejados)]
# Out:
# ANO             2009  2010       2011       2012       2013       2014  \
# SENADOR
# EDUARDO AMORIM   0.0   0.0  171722.48  223606.44  319137.84  186015.71
#
# ANO                   2015       2016       2017       2018      2019  2020  \
# SENADOR
# EDUARDO AMORIM  4385676.93  306258.14  332653.23  286636.38  12810.46   0.0
#
# ANO             2021  2022       Total
# SENADOR
# EDUARDO AMORIM   0.0   0.0  6224517.61

# %%
(df[df['Year']==2107]).head()
# Out:
#          ANO  MES             SENADOR  \
# 204793  2017    9  JOAO ALBERTO SOUZA
#
#                                              TIPO_DESPESA            CNPJ_CPF  \
# 204793  Passagens aéreas, aquáticas e terrestres nacio...  16.978.175/0001-08
#
#                           FORNECEDOR DOCUMENTO       DATA  \
# 204793  ADRIA VIAGENS E TURISMO LTDA    CJIRVG 2107-08-29
#
#                                              DETALHAMENTO  VALOR_REEMBOLSADO  \
# 204793  Companhia Aérea: GOL, Localizador: CJIRVG. Pas...            1184.79
#
#         COD_DOCUMENTO  Year
# 204793      2076233.0  2107

# %%
df['TIPO_DESPESA'].unique()
# Out:
# array(['Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles.',
#        'Divulgação da atividade parlamentar',
#        'Locomoção, hospedagem, alimentação, combustíveis e lubrificantes',
#        'Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar',
#        'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos. ',
#        'Passagens aéreas, aquáticas e terrestres nacionais',
#        'Serviços de Segurança Privada',
#        'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos.'],
#       dtype=object)
